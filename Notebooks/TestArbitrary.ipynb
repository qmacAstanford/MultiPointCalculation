# %%
from MultiPoint import arbitraryCopoly

# %%
arbitraryCopoly.test_arb_int()

# %%
import numpy as np

filename = '../meth'
L_poly = 1.7*(10**5)

k_vals = np.logspace(-3,0.2,20)

out = arbitraryCopoly.arb_int(filename, L_poly, k_vals, select = 'AA')

import matplotlib.pyplot as plt

# %%
plt.semilogx(k_vals/(38.0),np.array(out)/(L_poly**2))
plt.xlabel('k (nm^-1)')
plt.ylabel('S_AA')
plt.show()
# Out:
# /home/users/qmac/.anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:492: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
import GAMcalc
import propagator 
import numpy as np

# %%
import importlib

# %%
importlib.reload(GAMcalc)
# Out:
# <module 'GAMcalc' from '/home/users/qmac/BetterDoc/MultiPointCalculation/MultiPoint/GAMcalc.py'>

# %%
k_vals = np.logspace(-3,0.2,20)


pset=propagator.prop_set(nlam=1)
N = 1.7*(10**5)
PHIP = 0.07
CHIAS = 0.001
CHIBS = CHIAS
CHIAB = 0.100
FA =0.5
Gamma = [GAMcalc.gamma2sol(pset, N, FA, PHIP, K, CHIAB, CHIAS, CHIBS, chainType='arbitrary') for K in k_vals]

# %%
mins = [min(np.real(np.linalg.eigvals(Gam))) for Gam in Gamma]
import matplotlib.pyplot as plt
plt.semilogx(k_vals/(38.0), mins,".-")
plt.xlabel('k (nm^-1)')
plt.ylabel('min eigenvalue of Gamma')
plt.show()

# %%
k_vals[np.argmin(mins)]
# Out:
# 0.022251967709560273
